# %%
from numpy import load
import matplotlib.pyplot as plt

data = load('data/img_output/histogram_all_full.npz')
lst = data.files
for item in lst:
    plt.hist(data[item].ravel(),256,[0,256]); plt.show()
    #print(item)
    #print(data[item])

# %%
from osgeo import gdal
import matplotlib.pyplot as plt



ds = gdal.Open('data/crop_yield-data_image/5_35.tif').ReadAsArray()

im = plt.imshow(ds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_206896\2512732205.py in <module>
#       6 ds = gdal.Open('data/crop_yield-data_image/5_35.tif').ReadAsArray()
#       7
# ----> 8 im = plt.imshow(ds)
#
# C:\ProgramData\Anaconda3\envs\crop_yield_prediction\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     457                 "parameter will become keyword-only %(removal)s.",
#     458                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459         return func(*args, **kwargs)
#     460
#     461     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ...

# %%
import rasterio
from rasterio.plot import show
fp = r'data/crop_yield-data_image/5_35.tif'
img = rasterio.open(fp)
show(img)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_206896\1252824823.py in <module>
# ----> 1 import rasterio
#       2 from rasterio.plot import show
#       3 fp = r'data/crop_yield-data_image/5_35.tif'
#       4 img = rasterio.open(fp)
#       5 show(img)
#
# ModuleNotFoundError: No module named 'rasterio'

# %%
from osgeo import gdal
import matplotlib.pyplot as plt
dataset = gdal.Open('data/crop_yield-data_image/5_35.tif', gdal.GA_ReadOnly)
# Note GetRasterBand() takes band no. starting from 1 not 0
band = dataset.GetRasterBand(12)
arr = band.ReadAsArray()
plt.imshow(arr)

# %%
#from osgeo import gdal

#dataset = gdal.Open('data/crop_yield-data_image/5_35.tif', gdal.GA_ReadOnly)
# For no. of bands and resolution
dataset.RasterCount, dataset.RasterXSize, dataset.RasterYSize
# Out:
# (4368, 100, 136)

# %%
#img = dataset
# stats about image
band.GetStatistics( True, True )
# Out:
# [0.0, 5712.0, 1670.0607352941176, 1416.5236219203275]
